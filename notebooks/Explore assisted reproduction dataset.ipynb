# %%
import pandas
import missingno as msno
import numpy as np

# %%
data = pandas.read_excel("../data/data-assisted-reproduction/fettsyrer spermier VITAS sædkvalitet (2).xlsx", skiprows=4).drop("Unnamed: 0",axis=1)
data = data.replace(r'\s+', np.nan, regex=True)

# %%
display(data.T)
# Out:
#                                    0           1           2           3    \
# Vitas ID                           NaN    1.000000    2.000000         NaN
# HIOA/OsloMet_ID              101.00000  301.000000  302.000000  303.000000
# Spermie_konsentrasjon         32.87000  106.200000   17.650000    0.000000
# Totalantallspermier           90.72120  446.040000   69.894000    0.000000
# Ejakulat_volum                 2.76000    4.200000    3.960000    1.370000
# Levende_spermier_%            86.75000   52.500000   95.000000         NaN
# Normale_spermier_%             4.00000    2.500000    0.500000         NaN
# Hodefeil_%                    89.75000   97.000000   99.500000         NaN
# Midstykkefeil_%               30.25000   22.000000   43.250000         NaN
# Halefeil_%                     6.25000   33.500000   10.500000         NaN
# Cytoplasmisk_dråpe_%           5.75000    3.700000    9.250000         NaN
# ...

# %%
msno.matrix(data)
import matplotlib.pyplot as plt
plt.show()
